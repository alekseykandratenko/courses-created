# %% [markdown]
# # Ejercicios de Fundamentos de Python

# %% [markdown]
# ## 1. Variables y Tipos de Datos

# %% [markdown]
# ### Ejercicio 1: Tipos de datos básicos
# Crea variables con los siguientes tipos de datos y muéstralos por pantalla:
# - Un número entero
# - Un número decimal
# - Una cadena de texto
# - Un booleano

# %% [markdown]
# ### Ejercicio 2: Conversión de tipos
# Crea una variable con el número "15.8" como string y conviértelo a:
# - Número entero
# - Número decimal

# %% [markdown]
# ## 2. Operadores y Expresiones

# %% [markdown]
# ### Ejercicio 1: Calculadora básica
# Crea un programa que:
# - Pida dos números al usuario
# - Realice las operaciones: suma, resta, multiplicación y división
# - Muestre los resultados

# %% [markdown]
# ### Ejercicio 2: Operadores de comparación
# Escribe un programa que compare dos números e indique:
# - Si son iguales
# - Cuál es mayor
# - Cuál es menor
#
# Los números deben ser introducidos por el usuario.

# %% [markdown]
# ## 3. Cadenas de texto

# %% [markdown]
# ### Ejercicio 1: Manipulación de strings
# Crea un programa que:
# - Pida al usuario su nombre completo
# - Muestre el nombre en mayúsculas
# - Muestre el nombre en minúsculas
# - Muestre cuántos caracteres tiene
# - Muestre el primer y último carácter

# %% [markdown]
# ### Ejercicio 2: Formateo de strings
# Crea un programa que pida:
# - Nombre
# - Edad
# - Ciudad
#
# Y muestre el mensaje: "Me llamo [nombre], tengo [edad] años y vivo en [ciudad]"

# %% [markdown]
# ## 4. Listas

# %% [markdown]
# ### Ejercicio 1: Gestión de lista de compras
# Crea un programa que:
# - Cree una lista vacía llamada "compras"
# - Permita añadir 5 productos
# - Muestre la lista
# - Permita eliminar un producto
# - Muestre la lista final

# %% [markdown]
# ### Ejercicio 2: Operaciones con listas
# Crea una lista de números y:
# - Calcula la suma de todos los números
# - Encuentra el número mayor y menor
# - Ordena la lista de menor a mayor
# - Elimina los números duplicados

# %% [markdown]
# ## 5. Estructuras de Control

# %% [markdown]
# ### Ejercicio 1: Validador de edad
# Crea un programa que:
# - Pida la edad al usuario
# - Determine si es:
#   - Menor de edad (< 18)
#   - Adulto (18-65)
#   - Adulto mayor (> 65)

# %% [markdown]
# ### Ejercicio 2: Calculadora de notas
# Crea un programa que:
# - Pida una calificación numérica (0-100)
# - Muestre la calificación en letra:
#    * A (90-100)
#    * B (80-89)
#    * C (70-79)
#    * D (60-69)
#    * F (0-59)

# %% [markdown]
# ## 6. Bucles

# %% [markdown]
# ### Ejercicio 1: Tabla de multiplicar
# Crea un programa que:
# - Pida un número al usuario
# - Muestre su tabla de multiplicar del 1 al 10
# - Use un bucle for

# %% [markdown]
# ### Ejercicio 2: Adivina el número
# Crea un programa que:
# - Genere un número aleatorio entre 1 y 100
# - Pida al usuario que adivine el número
# - De pistas (mayor o menor)
# - Cuente los intentos
# - Use un bucle while

# %%
import random
